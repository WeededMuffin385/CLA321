# %% [markdown]
# # Shut down k3d cluster

# %%
# %%bash
#
# k3d cluster stop dev

# %% [markdown]
# # Start k3d cluster

# %%
# %%bash
#
# k3d cluster start dev

# %% [markdown]
# # Clean GitLab Container Registry

# %%
# %%bash
#
# docker exec -it gitlab gitlab-ctl registry-garbage-collect -m

# %% [markdown]
# # Recreate Traefik on Docker Compose

# %%
# %%bash
#
# docker compose up -d --build --force-recreate traefik

# %% [markdown]
# # Apply K8s Ingress parameters

# %%
# %%bash
#
# kubectl apply -f k8s/hello_world_service/ingress.yaml
