# %% [markdown]
# getting GitLab token

# %%
import os
import subprocess
import time

import requests

GITLAB_EXTERNAL_URL = "http://gitlab.localhost"
GITLAB_INTERNAL_URL = "http://gitlab"

GITLAB_TOKEN = os.environ["GITLAB_ROOT_TOKEN"]

PROJECT_NAME = "demo"
PROJECT_PATH = "demo"

RUNNER_CONTAINER = "gitlab_runner"
RUNNER_DESCRIPTION = "local-docker-runner"

session = requests.Session()
session.headers.update({
    "PRIVATE-TOKEN": GITLAB_TOKEN,
})
